# %% [markdown]
# <a href="https://colab.research.google.com/github/dadakhalander/ml/blob/main/airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
file_path = 'Airbnb_Open_Data.csv'
df = pd.read_csv(file_path)

# %%
df = pd.read_csv("Airbnb_Open_Data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101753 entries, 0 to 102057
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              101753 non-null  float64
#  1   host id                         101753 non-null  float64
#  2   host_identity_verified          101753 non-null  object
#  3   neighbourhood group             101753 non-null  object
#  4   neighbourhood                   101753 non-null  object
#  5   lat                             101753 non-null  float64
#  6   long                            101753 non-null  float64
#  7   instant_bookable                101753 non-null  bool
#  8   cancellation_policy             101753 non-null  object
#  9   room type                       101753 non-null  object
#  10  Construction year               101753 non-null  float64
#  11  price                           101753 non-null  object
# ...

# %%
df.head(5).T
# Out:
#                                                                                 0  \
# id                                                                        1001254
# NAME                                           Clean & quiet apt home by the park
# host id                                                               80014485718
# host_identity_verified                                                unconfirmed
# host name                                                                Madaline
# neighbourhood group                                                      Brooklyn
# neighbourhood                                                          Kensington
# lat                                                                      40.64749
# long                                                                    -73.97237
# country                                                             United States
# ...

# %%
df.tail()
# Out:
#              id                              NAME      host id  \
# 102594  6092437        Spare room in Williamsburg  12312296767
# 102595  6092990     Best Location near Columbia U  77864383453
# 102596  6093542    Comfy, bright room in Brooklyn  69050334417
# 102597  6094094  Big Studio-One Stop from Midtown  11160591270
# 102598  6094647              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# 102594               verified         Krik            Brooklyn
# 102595            unconfirmed        Mifan           Manhattan
# 102596            unconfirmed        Megan            Brooklyn
# 102597            unconfirmed  Christopher              Queens
# 102598            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...  \
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# ...

# %%
df.shape
# Out:
# (102599, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
df.describe()
# Out:
#                  id       host id            lat           long  \
# count  1.025990e+05  1.025990e+05  102591.000000  102591.000000
# mean   2.914623e+07  4.925411e+10      40.728094     -73.949644
# std    1.625751e+07  2.853900e+10       0.055857       0.049521
# min    1.001254e+06  1.236005e+08      40.499790     -74.249840
# 25%    1.508581e+07  2.458333e+10      40.688740     -73.982580
# 50%    2.913660e+07  4.911774e+10      40.722290     -73.954440
# 75%    4.320120e+07  7.399650e+10      40.762760     -73.932350
# max    5.736742e+07  9.876313e+10      40.916970     -73.705220
#
#        Construction year  minimum nights  number of reviews  \
# count      102385.000000   102190.000000      102416.000000
# mean         2012.487464        8.135845          27.483743
# std             5.765556       30.553781          49.508954
# min          2003.000000    -1223.000000           0.000000
# 25%          2007.000000        2.000000           1.000000
# ...

# %%
df.describe(include='object').T
# Out:
#                          count unique                  top    freq
# NAME                    102349  61281  Home away from home      33
# host_identity_verified  102310      2          unconfirmed   51200
# host name               102193  13190              Michael     881
# neighbourhood group     102570      7            Manhattan   43792
# neighbourhood           102583    224   Bedford-Stuyvesant    7937
# country                 102067      1        United States  102067
# country code            102468      1                   US  102468
# instant_bookable        102494      2                False   51474
# cancellation_policy     102523      3             moderate   34343
# room type               102599      4      Entire home/apt   53701
# price                   102352   1151                $206      137
# service fee             102326    231                 $41      526
# last review              86706   2477            6/23/2019    2443
# ...

# %%
df.describe(include='float').T
# Out:
#                                    count         mean         std         min  \
# lat                             102591.0    40.728094    0.055857    40.49979
# long                            102591.0   -73.949644    0.049521   -74.24984
# Construction year               102385.0  2012.487464    5.765556  2003.00000
# minimum nights                  102190.0     8.135845   30.553781 -1223.00000
# number of reviews               102416.0    27.483743   49.508954     0.00000
# reviews per month                86720.0     1.374022    1.746621     0.01000
# review rate number              102273.0     3.279106    1.284657     1.00000
# calculated host listings count  102280.0     7.936605   32.218780     1.00000
# availability 365                102151.0   141.133254  135.435024   -10.00000
#
#                                        25%         50%         75%         max
# lat                               40.68874    40.72229    40.76276    40.91697
# ...

# %%
df.isnull().sum()
# Out:
# id                                     0
# NAME                                 250
# host id                                0
# host_identity_verified               289
# host name                            406
# neighbourhood group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# room type                              0
# Construction year                    214
# price                                247
# service fee                          273
# minimum nights                       409
# number of reviews                    183
# last review                        15893
# reviews per month                  15879
# review rate number                   326
# calculated host listings count       319
# ...

# %%
df.duplicated().sum()
# Out:
# 541

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop(columns = ['license'], inplace = True)

# %%
df.isnull().sum()
# Out:
# id                                    0
# NAME                                250
# host id                               0
# host_identity_verified              289
# host name                           404
# neighbourhood group                  29
# neighbourhood                        16
# lat                                   8
# long                                  8
# country                             532
# country code                        131
# instant_bookable                    105
# cancellation_policy                  76
# room type                             0
# Construction year                   214
# price                               247
# service fee                         273
# minimum nights                      400
# number of reviews                   183
# last review                       15832
# reviews per month                 15818
# review rate number                  319
# calculated host listings count      319
# ...

# %%
df['NAME'].value_counts()
# Out:
# NAME
# Home away from home                                  33
# Hillside Hotel                                       30
# Water View King Bed Hotel Room                       30
# Brooklyn Apartment                                   27
# New york Multi-unit building                         27
#                                                      ..
# Modern & trendy serenity—great High Line location     1
# Quiet, light-filled, Soho apartment                   1
# Sunny and cozy room 10 minutes from Times Sq.61F3     1
# 1 bedroom apartment across the Central Park           1
# Parisian Style Apartment in Heart of Brooklyn         1
# Name: count, Length: 61281, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                                    0
# NAME                                250
# host id                               0
# host_identity_verified              289
# host name                           404
# neighbourhood group                  29
# neighbourhood                        16
# lat                                   8
# long                                  8
# country                             532
# country code                        131
# instant_bookable                    105
# cancellation_policy                  76
# room type                             0
# Construction year                   214
# price                               247
# service fee                         273
# minimum nights                      400
# number of reviews                   183
# last review                       15832
# reviews per month                 15818
# review rate number                  319
# calculated host listings count      319
# ...

# %%
df.head(5).T
# Out:
#                                                                                 0  \
# id                                                                        1001254
# NAME                                           Clean & quiet apt home by the park
# host id                                                               80014485718
# host_identity_verified                                                unconfirmed
# host name                                                                Madaline
# neighbourhood group                                                      Brooklyn
# neighbourhood                                                          Kensington
# lat                                                                      40.64749
# long                                                                    -73.97237
# country                                                             United States
# ...

# %%
df.drop(columns = ['NAME'], inplace = True)

# %%
df.head(10).T
# Out:
#                                                                                 0  \
# id                                                                        1001254
# host id                                                               80014485718
# host_identity_verified                                                unconfirmed
# host name                                                                Madaline
# neighbourhood group                                                      Brooklyn
# neighbourhood                                                          Kensington
# lat                                                                      40.64749
# long                                                                    -73.97237
# country                                                             United States
# country code                                                                   US
# ...

# %%
df['host_identity_verified'].value_counts()
# Out:
# host_identity_verified
# unconfirmed    50944
# verified       50825
# Name: count, dtype: int64

# %%
for i in df.select_dtypes(include="number").columns:
  sns.histplot(data=df,x=i)
  plt.show()

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['id', 'host id', 'lat', 'long', 'Construction year', 'minimum nights',
#        'number of reviews', 'reviews per month', 'review rate number',
#        'calculated host listings count', 'availability 365'],
#       dtype='object')

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['host_identity_verified', 'host name', 'neighbourhood group',
#        'neighbourhood', 'country', 'country code', 'instant_bookable',
#        'cancellation_policy', 'room type', 'price', 'service fee',
#        'last review', 'house_rules'],
#       dtype='object')

# %%
for i in [ 'host id', 'lat', 'long', 'Construction year', 'minimum nights',
       'number of reviews', 'reviews per month', 'review rate number',
       'calculated host listings count', 'availability 365']:

      sns.scatterplot(data=df,x=i,y="id")
      plt.show()

# %%
a=df.select_dtypes(include="number").corr()

# %%
sns.heatmap(a)
# Out:
# <Axes: >

# %%
df.drop(columns = ['host name'], inplace = True)

# %%
df['neighbourhood group'].fillna(df['neighbourhood group'].mode()[0], inplace = True)

# %%
df['neighbourhood'].value_counts()
# Out:
# neighbourhood
# Bedford-Stuyvesant        7898
# Williamsburg              7732
# Harlem                    5441
# Bushwick                  4956
# Hell's Kitchen            3949
#                           ...
# Willowbrook                  3
# Gerritsen Beach              3
# Fort Wadsworth               2
# Glen Oaks                    2
# Chelsea, Staten Island       1
# Name: count, Length: 224, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                                    0
# host id                               0
# host_identity_verified              289
# neighbourhood group                   0
# neighbourhood                        16
# lat                                   8
# long                                  8
# country                             532
# country code                        131
# instant_bookable                    105
# cancellation_policy                  76
# room type                             0
# Construction year                   214
# price                               247
# service fee                         273
# minimum nights                      400
# number of reviews                   183
# last review                       15832
# reviews per month                 15818
# review rate number                  319
# calculated host listings count      319
# availability 365                    448
# house_rules                       51842
# dtype: int64

# %%
from sklearn.impute import KNNImputer
imputer=KNNImputer()

# %%
for i in df.select_dtypes(include="number").columns:
  df[i]=imputer.fit_transform(df[[i]])

# %%
df.isnull().sum()
# Out:
# id                                    0
# host id                               0
# host_identity_verified              289
# neighbourhood group                   0
# neighbourhood                        16
# lat                                   0
# long                                  0
# country                             532
# country code                        131
# instant_bookable                    105
# cancellation_policy                  76
# room type                             0
# Construction year                     0
# price                               247
# service fee                         273
# minimum nights                        0
# number of reviews                     0
# last review                       15832
# reviews per month                     0
# review rate number                    0
# calculated host listings count        0
# availability 365                      0
# house_rules                       51842
# dtype: int64

# %%
df['host_identity_verified']
# Out:
# 0         unconfirmed
# 1            verified
# 2                 NaN
# 3         unconfirmed
# 4            verified
#              ...
# 102053    unconfirmed
# 102054       verified
# 102055       verified
# 102056    unconfirmed
# 102057       verified
# Name: host_identity_verified, Length: 102058, dtype: object

# %%
df.dropna(subset =['host_identity_verified'], inplace = True)

# %%
df.isna().sum()
# Out:
# id                                    0
# host id                               0
# host_identity_verified                0
# neighbourhood group                   0
# neighbourhood                        16
# lat                                   0
# long                                  0
# country                             529
# country code                        123
# instant_bookable                     97
# cancellation_policy                  73
# room type                             0
# Construction year                     0
# price                               243
# service fee                         272
# minimum nights                        0
# number of reviews                     0
# last review                       15790
# reviews per month                     0
# review rate number                    0
# calculated host listings count        0
# availability 365                      0
# house_rules                       51723
# dtype: int64

# %%
df['neighbourhood group'].fillna(df['neighbourhood group'].mode()[0], inplace = True)

# %%
df.isna().sum()
# Out:
# id                                    0
# host id                               0
# host_identity_verified                0
# neighbourhood group                   0
# neighbourhood                        16
# lat                                   0
# long                                  0
# country                             529
# country code                        123
# instant_bookable                     97
# cancellation_policy                  73
# room type                             0
# Construction year                     0
# price                               243
# service fee                         272
# minimum nights                        0
# number of reviews                     0
# last review                       15790
# reviews per month                     0
# review rate number                    0
# calculated host listings count        0
# availability 365                      0
# house_rules                       51723
# dtype: int64

# %%
df['lat'].value_counts()
# Out:
# lat
# 40.76411    36
# 40.71813    32
# 40.76125    28
# 40.73756    26
# 40.76106    25
#             ..
# 40.66649     1
# 40.62918     1
# 40.76426     1
# 40.75170     1
# 40.83083     1
# Name: count, Length: 21972, dtype: int64

# %%
df.dropna(subset = ['lat', 'neighbourhood', 'long'], inplace = True)

# %%
df.isnull().sum()
# Out:
# id                                    0
# host id                               0
# host_identity_verified                0
# neighbourhood group                   0
# neighbourhood                         0
# lat                                   0
# long                                  0
# country                             527
# country code                        121
# instant_bookable                     95
# cancellation_policy                  71
# room type                             0
# Construction year                     0
# price                               242
# service fee                         272
# minimum nights                        0
# number of reviews                     0
# last review                       15790
# reviews per month                     0
# review rate number                    0
# calculated host listings count        0
# availability 365                      0
# house_rules                       51717
# dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# United States    101226
# Name: count, dtype: int64

# %%
df['country code'].value_counts()
# Out:
# country code
# US    101632
# Name: count, dtype: int64

# %%
df.drop(columns = ['country', 'country code'], inplace = True)

# %%
df.isna().sum()
# Out:
# id                                    0
# host id                               0
# host_identity_verified                0
# neighbourhood group                   0
# neighbourhood                         0
# lat                                   0
# long                                  0
# instant_bookable                     95
# cancellation_policy                  71
# room type                             0
# Construction year                     0
# price                               242
# service fee                         272
# minimum nights                        0
# number of reviews                     0
# last review                       15790
# reviews per month                     0
# review rate number                    0
# calculated host listings count        0
# availability 365                      0
# house_rules                       51717
# dtype: int64

# %%
df['instant_bookable'].value_counts()
# Out:
# instant_bookable
# False    51037
# True     50621
# Name: count, dtype: int64

# %%
df['instant_bookable'].fillna(df['instant_bookable'].mode()[0], inplace = True)

# %%
df.isna().sum()
# Out:
# id                                    0
# host id                               0
# host_identity_verified                0
# neighbourhood group                   0
# neighbourhood                         0
# lat                                   0
# long                                  0
# instant_bookable                      0
# cancellation_policy                  71
# room type                             0
# Construction year                     0
# price                               242
# service fee                         272
# minimum nights                        0
# number of reviews                     0
# last review                       15790
# reviews per month                     0
# review rate number                    0
# calculated host listings count        0
# availability 365                      0
# house_rules                       51717
# dtype: int64

# %%
df['cancellation_policy'].fillna(df['cancellation_policy'].mode()[0], inplace = True)

# %%
df.isna().sum()
# Out:
# id                                    0
# host id                               0
# host_identity_verified                0
# neighbourhood group                   0
# neighbourhood                         0
# lat                                   0
# long                                  0
# instant_bookable                      0
# cancellation_policy                   0
# room type                             0
# Construction year                     0
# price                               242
# service fee                         272
# minimum nights                        0
# number of reviews                     0
# last review                       15790
# reviews per month                     0
# review rate number                    0
# calculated host listings count        0
# availability 365                      0
# house_rules                       51717
# dtype: int64

# %%
df['cancellation_policy'].value_counts()
# Out:
# cancellation_policy
# moderate    34137
# strict      33833
# flexible    33783
# Name: count, dtype: int64

# %%
df['Construction year'].value_counts()
# Out:
# Construction year
# 2014.00000    5207
# 2006.00000    5175
# 2008.00000    5174
# 2019.00000    5165
# 2009.00000    5126
# 2020.00000    5120
# 2010.00000    5115
# 2022.00000    5105
# 2012.00000    5087
# 2003.00000    5083
# 2007.00000    5076
# 2005.00000    5075
# 2015.00000    5056
# 2017.00000    5017
# 2011.00000    5016
# 2018.00000    5005
# 2021.00000    4997
# 2004.00000    4991
# 2013.00000    4986
# 2016.00000    4980
# 2012.48809     197
# Name: count, dtype: int64

# %%
from pickle import TRUE
sns.distplot(df['Construction year'], kde = True)
# Out:
# <Axes: xlabel='Construction year', ylabel='Density'>

# %%
sns.histplot(df['Construction year'], kde = True)
# Out:
# <Axes: xlabel='Construction year', ylabel='Count'>

# %%
df['price'].value_counts()
# Out:
# price
# $206       135
# $1,056     131
# $481       129
# $833       127
# $573       126
#           ...
# $923        57
# $369        57
# $786        53
# $89         52
# $187        52
# Name: count, Length: 1151, dtype: int64

# %%
df['price'].fillna(df['price'].mode()[0], inplace = True)

# %%
df.isna().sum()
# Out:
# id                                    0
# host id                               0
# host_identity_verified                0
# neighbourhood group                   0
# neighbourhood                         0
# lat                                   0
# long                                  0
# instant_bookable                      0
# cancellation_policy                   0
# room type                             0
# Construction year                     0
# price                                 0
# service fee                         272
# minimum nights                        0
# number of reviews                     0
# last review                       15790
# reviews per month                     0
# review rate number                    0
# calculated host listings count        0
# availability 365                      0
# house_rules                       51717
# dtype: int64

# %%
df['price'].value_counts()
# Out:
# price
# $206       377
# $1,056     131
# $481       129
# $833       127
# $573       126
#           ...
# $923        57
# $369        57
# $786        53
# $89         52
# $187        52
# Name: count, Length: 1151, dtype: int64

# %%
df['service fee']
# Out:
# 0         $193
# 1          $28
# 3          $74
# 4          $41
# 5         $115
#           ...
# 102053      NaN
# 102054      NaN
# 102055      NaN
# 102056      NaN
# 102057      NaN
# Name: service fee, Length: 101753, dtype: object

# %%
df['service fee'].fillna(df['service fee'].mode()[0], inplace = True)

# %%
df.isna().sum()
# Out:
# id                                    0
# host id                               0
# host_identity_verified                0
# neighbourhood group                   0
# neighbourhood                         0
# lat                                   0
# long                                  0
# instant_bookable                      0
# cancellation_policy                   0
# room type                             0
# Construction year                     0
# price                                 0
# service fee                           0
# minimum nights                        0
# number of reviews                     0
# last review                       15790
# reviews per month                     0
# review rate number                    0
# calculated host listings count        0
# availability 365                      0
# house_rules                       51717
# dtype: int64

# %%
sns.distplot(df['minimum nights'])
# Out:
# <Axes: xlabel='minimum nights', ylabel='Density'>

# %%
sns.distplot(df['number of reviews'])
# Out:
# <Axes: xlabel='number of reviews', ylabel='Density'>

# %%
df['last review']
# Out:
# 0         10/19/2021
# 1          5/21/2022
# 3           7/5/2019
# 4         11/19/2018
# 5          6/22/2019
#              ...
# 102053     3/27/2019
# 102054     8/31/2017
# 102055     6/26/2019
# 102056           NaN
# 102057     6/15/2019
# Name: last review, Length: 101753, dtype: object

# %%
df['last review'].value_counts()
# Out:
# last review
# 6/23/2019    2421
# 6/30/2019    2213
# 7/1/2019     2193
# 6/24/2019    1501
# 7/7/2019     1145
#              ...
# 9/4/2020        1
# 9/2/2020        1
# 6/6/2014        1
# 4/3/2022        1
# 8/15/2014       1
# Name: count, Length: 2476, dtype: int64

# %%
df['last review'].fillna('Unknown', inplace = True)

# %%
df.isna().sum()
# Out:
# id                                    0
# host id                               0
# host_identity_verified                0
# neighbourhood group                   0
# neighbourhood                         0
# lat                                   0
# long                                  0
# instant_bookable                      0
# cancellation_policy                   0
# room type                             0
# Construction year                     0
# price                                 0
# service fee                           0
# minimum nights                        0
# number of reviews                     0
# last review                           0
# reviews per month                     0
# review rate number                    0
# calculated host listings count        0
# availability 365                      0
# house_rules                       51717
# dtype: int64

# %%
sns.distplot(df['review rate number'])
# Out:
# <Axes: xlabel='review rate number', ylabel='Density'>

# %%
sns.distplot(df['availability 365'])
# Out:
# <Axes: xlabel='availability 365', ylabel='Density'>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101753 entries, 0 to 102057
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              101753 non-null  float64
#  1   host id                         101753 non-null  float64
#  2   host_identity_verified          101753 non-null  object
#  3   neighbourhood group             101753 non-null  object
#  4   neighbourhood                   101753 non-null  object
#  5   lat                             101753 non-null  float64
#  6   long                            101753 non-null  float64
#  7   instant_bookable                101753 non-null  bool
#  8   cancellation_policy             101753 non-null  object
#  9   room type                       101753 non-null  object
#  10  Construction year               101753 non-null  float64
#  11  price                           101753 non-null  object
# ...

# %%
df.head(2).T
# Out:
#                                                                                 0  \
# id                                                                      1001254.0
# host id                                                             80014485718.0
# host_identity_verified                                                unconfirmed
# neighbourhood group                                                      Brooklyn
# neighbourhood                                                          Kensington
# lat                                                                      40.64749
# long                                                                    -73.97237
# instant_bookable                                                            False
# cancellation_policy                                                        strict
# room type                                                            Private room
# ...

# %%
sns.barplot(y = 'reviews per month', x = 'room type', data = df, ci = None)
plt.title('show relation between room type and reviews per month')
plt.show()

# %%
sns.barplot(x = 'room type',y = 'availability 365', data = df, ci = None)
plt.show()

# %%
df.head()
# Out:
#           id       host id host_identity_verified neighbourhood group  \
# 0  1001254.0  8.001449e+10            unconfirmed            Brooklyn
# 1  1002102.0  5.233517e+10               verified           Manhattan
# 3  1002755.0  8.509833e+10            unconfirmed            Brooklyn
# 4  1003689.0  9.203760e+10               verified           Manhattan
# 5  1004098.0  4.549855e+10               verified           Manhattan
#
#   neighbourhood       lat      long  instant_bookable cancellation_policy  \
# 0    Kensington  40.64749 -73.97237             False              strict
# 1       Midtown  40.75362 -73.98377             False            moderate
# 3  Clinton Hill  40.68514 -73.95976              True            moderate
# 4   East Harlem  40.79851 -73.94399             False            moderate
# 5   Murray Hill  40.74767 -73.97500              True            flexible
#
#          room type  ...  price service fee minimum nights  number of reviews  \
# ...

# %% [markdown]
# PATTERN RECOGNITION

# %%
df.neighbourhood .value_counts()
# Out:
# neighbourhood
# Bedford-Stuyvesant        7875
# Williamsburg              7709
# Harlem                    5417
# Bushwick                  4947
# Hell's Kitchen            3941
#                           ...
# Rossville                    3
# Woodrow                      3
# Fort Wadsworth               2
# Glen Oaks                    2
# Chelsea, Staten Island       1
# Name: count, Length: 224, dtype: int64

# %%
df['neighbourhood group'].value_counts()
# Out:
# neighbourhood group
# Manhattan        43453
# Brooklyn         41499
# Queens           13170
# Bronx             2685
# Staten Island      944
# brookln              1
# manhatan             1
# Name: count, dtype: int64

# %%
# Correct the column name to 'neighbourhood group'
df[["neighbourhood group","neighbourhood"]].head()
# Out:
#   neighbourhood group neighbourhood
# 0            Brooklyn    Kensington
# 1           Manhattan       Midtown
# 3            Brooklyn  Clinton Hill
# 4           Manhattan   East Harlem
# 5           Manhattan   Murray Hill

# %%
print ("unique_values",df[["neighbourhood group","neighbourhood"]].nunique())
# Out:
# unique_values neighbourhood group      7
# neighbourhood          224
# dtype: int64

# %%
top_neighborhoods = df["neighbourhood group"].value_counts()

# %%
top_neighborhoods.plot(kind='bar', color='green')
plt.title('neighbourhood_group Airbnb Locations')
plt.xlabel('neighbourhood_group')
plt.ylabel('Number of Airbnbs')
plt.show()

# %%
top_neighborhoods.plot(kind='pie', color='skyblue')
plt.title('Top 10 Neighborhoods with the Most Airbnb Locations')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Airbnbs')
plt.show()

# %% [markdown]
# summary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101753 entries, 0 to 102057
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              101753 non-null  float64
#  1   host id                         101753 non-null  float64
#  2   host_identity_verified          101753 non-null  object
#  3   neighbourhood group             101753 non-null  object
#  4   neighbourhood                   101753 non-null  object
#  5   lat                             101753 non-null  float64
#  6   long                            101753 non-null  float64
#  7   instant_bookable                101753 non-null  bool
#  8   cancellation_policy             101753 non-null  object
#  9   room type                       101753 non-null  object
#  10  Construction year               101753 non-null  float64
#  11  price                           101753 non-null  object
# ...

# %%
df[['price','service fee']].describe()
# Out:
#          price service fee
# count   101753      101753
# unique    1151         231
# top      $206        $216
# freq       377         792

# %%
sns.histplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
import sys

sys.getsizeof(df)
# Out:
# 84147798
